# %% [markdown]
# This notebook is for comparing outputs from the app to ensure accuracy

# %%
import pandas as pd
df = pd.read_csv("transaction_data.csv")
df.sample(10)
# Out:
#      entity_id  degree  small_tx_count    avg_amount  amount_variance  \
# 3200     E3200       5               0  44431.713935     1.144178e+09
# 2992     E2992       3               0  31181.725215     3.704812e+08
# 1398     E1398       5               0  28403.116956     7.847220e+08
# 2000     E2000       5               1  49983.718999     2.524022e+09
# 147      E0147       6               0  28492.847569     2.674281e+08
# 2095     E2095       6               0  48793.419213     1.071993e+09
# 358      E0358       5               0  40252.864684     3.818784e+09
# 3560     E3560       4               0  37933.578717     4.617264e+08
# 1653     E1653       5               0  57172.364297     1.898667e+09
# 2169     E2169       7               0  58735.764550     2.443264e+09
#
#       amount_skewness  high_value_ratio  cycle_score  clustering_coeff  \
# 3200         0.550089          0.000000     1.894010          0.088889
# ...

# %%
df["avg_amount"].mean()
# Out:
# np.float64(48755.84993196801)

# %%
df["kyc_risk_score"].sample(10)
# Out:
# 3760    0.148417
# 2267    0.057225
# 329     0.215187
# 1024    0.062672
# 2976    0.296984
# 1433    0.089648
# 1561    0.220799
# 97      0.068313
# 872     0.053459
# 3852    0.753193
# Name: kyc_risk_score, dtype: float64
